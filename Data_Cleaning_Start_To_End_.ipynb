# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
smartphones=pd.read_csv('/content/drive/MyDrive/dataset/smartphones - smartphones.csv')

# %%
smartphones['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                          171
# Memory Card Not Supported                                 112
# Android v12                                               107
# Memory Card Supported, upto 512 GB                        105
# Memory Card (Hybrid), upto 1 TB                            91
#                                                          ...
# Memory Card Supported, upto 48 GB                           1
# Memory Card (Hybrid), upto 2 TB                             1
# HarmonyOS                                                   1
# 48 MP Quad Rear Camera                                      1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera      1
# Name: count, Length: 63, dtype: int64

# %% [markdown]
# # Data Accessing
# # **Quality Issues**
#
# 1. **model** - some brands are written diiferently like OPPO(upper and lower) in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness` also rating in whole number i need float like 8.9
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 14 row= no gb there is battery given
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
#  missing values in camera card and os
# 20. datatype  of price and rating is incorrect `validity`
# data type of price and rating incorrect
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
smartphones.head(2)
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# ...

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
smartphones.duplicated().sum()
# Out:
# np.int64(0)

# %%
smartphones.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %% [markdown]
# # cleaning
# quality issue
# completeness,inconsistencies, accuracy,validity

# %%
smartphones.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# # validity issue
# 1. price - has unneccesary '₹' validity
# 2. price - has ',' between numbers validity

# %%
smartphones_copy=smartphones.copy()

# %%
smartphones_copy.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
smartphones_copy['price']=smartphones_copy['price'].str.replace('₹','').str.replace(',','').astype('int')

# %% [markdown]
# #1. index in excel starting from 2 but in data here index starting from 0

# %%
smartphones_copy=smartphones_copy.reset_index()

# %%
smartphones_copy['index']=smartphones_copy['index']+2

# %%
smartphones_copy
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# # problametic rows

# %%
processor_rows=set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows=set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows=set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows=set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows=set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows|ram_rows|battery_rows|display_rows|camera_rows)]# atleast one  coloumn problem
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
smartphones_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1020 non-null   int64
#  1   model      1020 non-null   object
#  2   price      1020 non-null   int64
#  3   rating     879 non-null    float64
#  4   sim        1020 non-null   object
#  5   processor  1020 non-null   object
#  6   ram        1020 non-null   object
#  7   battery    1020 non-null   object
#  8   display    1020 non-null   object
#  9   camera     1019 non-null   object
#  10  card       1013 non-null   object
#  11  os         1003 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 95.8+ KB

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]#every rows coloumn  has problem #feature phone
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]['price']
# Out:
# 640     1299
# 645     5490
# 647     1339
# 657     2799
# 665      958
# 748     3290
# 757      995
# 817     2239
# 882     4799
# 925     3999
# 927     1685
# 930     2099
# 1000    1999
# Name: price, dtype: int64

# %%
smartphones_copy=smartphones_copy[smartphones_copy['price']>3400]#dropping out because less than 3000 are not smart ones
smartphones_copy
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows|ram_rows|battery_rows|display_rows|camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %% [markdown]
# #processor - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) validity
# There is ipod on row 756 validity

# %%
smartphones_copy[smartphones_copy['index'].isin(processor_rows)]#qll are feature
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
len(processor_rows)
# Out:
# 17

# %%
smartphones_copy.drop([645,857,882,925],inplace=True)
# Out:
# <ipython-input-25-fcac0713b134>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones_copy.drop([645,857,882,925],inplace=True)

# %% [markdown]
# # ram memory
#  - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) validity 14 row= no gb there is battery given

# %%
smartphones_copy[smartphones_copy['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
smartphones_copy.drop(582,inplace=True)
# Out:
# <ipython-input-27-e87455e7c1d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones_copy.drop(582,inplace=True)

# %% [markdown]
# #battery -
# incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) validity

# %%
smartphones_copy.drop([376,754],inplace=True)
# Out:
# <ipython-input-28-9a52a5d9fb46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones_copy.drop([376,754],inplace=True)

# %%
temp_df=smartphones_copy[smartphones_copy['index'].isin(battery_rows)]
temp_df
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
x=temp_df.iloc[:,7:].shift(1,axis=1).values
x
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
x_index=temp_df.index

# %%
smartphones_copy.loc[x_index,temp_df.columns[7:]]=x

# %% [markdown]
# # display -
# incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) validity

# %%
smartphones_copy[smartphones_copy['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# # camera -
#  problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 )

# %%
len(camera_rows)
# Out:
# 64

# %% [markdown]
# 155,

# %%
smartphones_copy[smartphones_copy['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
smartphones_copy.drop([155,271],inplace=True)
# Out:
# <ipython-input-36-865e26ef3e42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartphones_copy.drop([155,271],inplace=True)

# %%
temp_df=smartphones_copy[smartphones_copy['index'].isin(camera_rows)]

# %%
temp_df

# %%
temp_df=temp_df[~temp_df['camera'].str.contains('MP')]#problematic

# %%
smartphones_copy.loc[temp_df.index,'camera']=temp_df['card'].values

# %%
temp_df

# %%
smartphones_copy[smartphones_copy['index'].isin(camera_rows)]

# %% [markdown]
# # card
# card - sometimes contains info about os and camera validity

# %%
smartphones_copy

# %%
temp_df=smartphones_copy[smartphones_copy['card'].str.contains('OS',na=False)]

# %%
x=temp_df.iloc[:,10:].shift(1,axis=1).values

# %%
x_index=temp_df.index

# %%
smartphones_copy.loc[x_index,temp_df.columns[10:]]=x

# %%
temp_df=smartphones_copy[smartphones_copy['card'].str.contains('Android',na=False)]

# %%
x=temp_df.iloc[:,10:].shift(1,axis=1).values

# %%
x

# %%
x_index=temp_df.index

# %%
smartphones_copy.loc[x_index,temp_df.columns[10:]]=x

# %%
temp_df.index

# %%
smartphones_copy.loc[temp_df.index,'card']=temp_df['card']

# %%
temp_df=smartphones_copy[smartphones_copy['card'].str.contains('MP',na=False)]

# %%
smartphones_copy.loc[temp_df.index,'card']='Memory Card Supported'

# %%
smartphones_copy['card'].value_counts()

# %%
temp_df=smartphones_copy[~smartphones_copy['card'].str.contains('Memory Card',na=False)]

# %%
temp_df.index

# %%
temp_df=smartphones_copy[smartphones_copy['card']=='Memory Card not Supported']

# %%
smartphones_copy.loc[temp_df.index,'card']='Memory Card Not Supported'

# %% [markdown]
# # os

# %%
temp_df=smartphones_copy[smartphones_copy['os'].str.contains('Memory Card Not Supported',na=False)]

# %%
smartphones_copy.loc[temp_df.index,'os']=np.nan

# %%
temp_df=smartphones_copy[smartphones_copy['os'].str.contains('Memory Card',na=False)]

# %%
temp_df.head(1)

# %%
x=temp_df.iloc[:,10:12].shift(-1,axis=1).values

# %%
x_index=temp_df.index

# %%
smartphones_copy.loc[x_index,temp_df.columns[10:12]]=x

# %%
smartphones_copy[smartphones_copy['os']=='Bluetooth']=np.nan

# %%
smartphones_copy['os'].value_counts()

# %% [markdown]
# # **Tidiness**

# %%
smartphones_copy.shape

# %%
smartphones_copy.isnull().sum()

# %%
smartphones_copy.head(1)

# %% [markdown]
# # model

# %%
brand_name=smartphones_copy['model'].str.split().str.get(0)

# %%
smartphones_copy.insert(1,'brand_name',brand_name)

# %%
smartphones_copy.head(10)

# %%
smartphones_copy['brand_name']=smartphones_copy['brand_name'].str.lower()

# %%
smartphones_copy.head(2)

# %% [markdown]
# # sim

# %% [markdown]
# NFC (Near Field Communication) in mobile devices is a short-range wireless technology enabling secure, contactless communication for tasks like mobile payments, data exchange, and device pairing, requiring devices to be in close proximity.

# %% [markdown]
# # Has 5g

# %%
smartphones_copy[smartphones_copy['sim'].str.contains('5G',na=False)]

# %%
Has_5g=smartphones_copy['sim'].str.contains('5G',na=False)

# %% [markdown]
# # NFC

# %%
smartphones_copy[smartphones_copy['sim'].str.contains('NFC',na=False)]

# %%
has_Nfc=smartphones_copy['sim'].str.contains('NFC',na=False)

# %% [markdown]
# # ir blaster

# %%
smartphones_copy['sim'].value_counts()

# %%
smartphones_copy[smartphones_copy['sim'].str.contains(' IR Blaster',na=False)]

# %%
Has_Ir=smartphones_copy['sim'].str.contains(' IR Blaster',na=False)

# %%
smartphones_copy.insert(6,'has_5g',Has_5g)

# %%
smartphones_copy.insert(7,'has_NFC',has_Nfc)

# %%
smartphones_copy.insert(8,'has_IR_Blaster',Has_Ir)

# %%
smartphones_copy.head(1)

# %% [markdown]
# # processor

# %%
smartphones_copy['processor'].value_counts()

# %%
Processor_name=  smartphones_copy['processor'].str.split(',').str.get(0)

# %%
Num_cores=  smartphones_copy['processor'].str.split(',').str.get(1)

# %%
Speed=  smartphones_copy['processor'].str.split(',').str.get(2)

# %%
smartphones_copy.insert(10,'processor_name',Processor_name)

# %%
smartphones_copy.insert(11,'num_cores',Num_cores)

# %%
smartphones_copy.insert(12,'Speed',Speed)

# %%
smartphones_copy.head(5)

# %%
pd.set_option('display.max_rows',None)

# %%
smartphones_copy['processor_name'].value_counts()

# %% [markdown]
# 800 mAh Battery
# 2000 mAh Battery
# 1 GB RAM
# 4 MB RAM
# Dual Core
# 1.77 MHz Processor
# No 3G
# Octa Core
# No Wifi

# %%
temp_df=smartphones_copy[smartphones_copy['processor_name'].str.strip().str.contains('Core',na=False)][['processor_name','num_cores','Speed']].shift(1,axis=1)

# %%
smartphones_copy.loc[temp_df.index,['processor_name','num_cores','Speed']]=temp_df.values

# %%
smartphones_copy['processor_name'].value_counts()

# %% [markdown]
# as per price these are feature phone

# %% [markdown]
#  1.77 MHz Processor

# %%
smartphones_copy['processor_name'].value_counts()

# %%
smartphones_copy[smartphones_copy['processor_name'].str.contains('28 nm',na=False)]

# %%
smartphones_copy.loc[856,'processor_name']='Mediatek MT6739'

# %%
smartphones_copy.loc[856]

# %%
smartphones_copy['processor_name'].value_counts()

# %%
Processor_name=smartphones_copy['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
smartphones_copy.insert(11,'processor_Brand',Processor_name)

# %%
smartphones_copy.head(1)

# %%
smartphones_copy['num_cores']=smartphones_copy['num_cores'].str.strip()

# %%
smartphones_copy['num_cores'].value_counts()

# %%
smartphones_copy['num_cores']=smartphones_copy['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core')

# %%
smartphones_copy['Speed']=smartphones_copy['Speed'].str.split().str.get(0).astype(float)

# %%
smartphones_copy

# %%
smartphones_copy.head(2)

# %%
smartphones_copy['ram'].value_counts()

# %%
import requests as re

# %%
capacity=smartphones_copy['ram'].str.split(',').str[0].str.extract(r'(\d+\s?(TB|GB|MB|KB|B))')[0]

# %%
smartphones_copy.insert(15,'RAM_capacity',capacity)

# %%
capacity=smartphones_copy['ram'].str.split(',').str[1].str.extract(r'(\d+\s?(TB|GB|MB|KB|B))')[0]

# %%
smartphones_copy.insert(16,'ROM_capacity',capacity)

# %%
smartphones_copy.head(1)

# %%
smartphones_copy['ram'].value_counts()

# %%
smartphones_copy['RAM_capacity'].value_counts()

# %%
smartphones_copy['ROM_capacity'].value_counts()

# %%
smartphones_copy[smartphones_copy['ROM_capacity'].isin(['16 MB', '128 MB'])]

# %%
smartphones_copy.drop(627,inplace=True)

# %%
smartphones_copy.head(3)

# %% [markdown]
# # battery

# %%
battery_capacity=smartphones_copy['battery'].str.split('with').str[0].str.extract(r'(\d+\s?(mAh))')[0]

# %%
smartphones_copy.insert(18,'battery_capacity',battery_capacity)

# %%
smartphones_copy['battery'][smartphones_copy['battery'].str.contains(' Fast Charging',na=False)]

# %%
smartphones_copy['battery'].str.split('with').str[1]

# %%
fast_charging=smartphones_copy['battery'].str.split('with').str[1]

# %%
smartphones_copy.insert(19,'fast_charging',fast_charging)

# %%
smartphones_copy.head(1)

# %% [markdown]
# # display

# %%
screensize=smartphones_copy['display'].str.strip().str.split(',').str[0]

# %%
smartphones_copy.insert(21,'screensize',screensize)

# %%
resolution=smartphones_copy['display'].str.strip().str.split(',').str[1].str.strip().str.split(' ').str[0]

# %%
smartphones_copy.insert(22,'resolution',resolution)

# %%
smartphones_copy.info()

# %%
refresh_rate=smartphones_copy['display'].str.strip().str.split(',').str.get(2).str.extract(r'(\d+\s?(Hz))')[0]

# %%
smartphones_copy.insert(23,'refresh_rate',refresh_rate)

# %%
smartphones_copy['refresh_rate'].fillna('60 Hz',inplace=True)

# %%
smartphones_copy.head(2)

# %%
smartphones_copy['refresh_rate'].value_counts()

# %% [markdown]
# #camera

# %%
df=smartphones_copy[smartphones_copy['camera']=='Foldable Display, Dual Display']

# %%
smartphones_copy.loc[df.index,'camera']='50 MP'

# %%
def camera_extractor(text):
  if isinstance(text, float):  # अगर text NaN (float) है तो उसे empty string बना दो
       return ''
  if 'Quad' in text:
    return '4'
  elif 'Triple' in text:
    return '3'
  elif 'Dual' in text:
    return '2'
  elif 'Missing' in text:
    return 'Missing'
  else:
    return '1'

# %%
num_of_rear_cameras=smartphones_copy['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
smartphones_copy.insert(25,'num_of_rear_cameras',num_of_rear_cameras)

# %%
num_of_front_cameras=smartphones_copy['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)

# %%
smartphones_copy.insert(26,'num_of_front_cameras',num_of_front_cameras)

# %%
rear_camera=smartphones_copy['camera'].str.strip().str.split('&').str.get(0)

# %%
smartphones_copy.insert(27,'rear_camera',rear_camera)

# %%
front=smartphones_copy['camera'].str.strip().str.split('&').str.get(1)

# %%
smartphones_copy.insert(28,'front_camera',front)

# %%
smartphones_copy.head(1)

# %%
smartphones_copy[smartphones_copy['rear_camera'].isnull()]

# %%
smartphones_copy.drop(486,inplace=True)

# %%
smartphones_copy['rear_camera']=smartphones_copy['rear_camera'].str.strip().str.split('+').str.get(0).str.extract(r'(\d+)')

# %%
smartphones_copy['rear_camera'].isnull().sum()

# %%
smartphones_copy.shape

# %%
smartphones_copy.head(2)

# %%
smartphones_copy['front_camera']=smartphones_copy['front_camera'].str.strip().str.split('+').str.get(0).str.extract(r'(\d+)')

# %% [markdown]
# # card-> extended memory

# %%
smartphones_copy['card'].fillna('Not Specified',inplace=True)

# %%
smartphones_copy['extended_memory']=smartphones_copy['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
temp_df=smartphones_copy[smartphones_copy['extended_memory'].str.contains('Android')]

# %%
smartphones_copy.loc[temp_df.index,'extended_memory']='Not Specified'

# %%
smartphones_copy['extended_memory'].value_counts()

# %%
pd.set_option('display.max_columns', None)

# %%
temp_df=smartphones_copy[smartphones_copy['extended_memory']=='Memory Card (Hybrid)']

# %%
smartphones_copy.loc[temp_df.index,'extended_memory']='256 GB(Hybrid)'

# %%
smartphones_copy

# %% [markdown]
# # os

# %%
smartphones_copy['os'].value_counts()

# %%
smartphones_copy['os'].fillna('android',inplace=True)

# %%
def os_extractor(text):
    if isinstance(text, float):  # NaN values handle करने के लिए
        return "Not Specified"
    elif 'Android' in text:
        return 'android'
    elif 'iOS' in text:
        return 'ios'
    else:
        return "Other"

# %%
smartphones_copy['os']=smartphones_copy['os'].apply(os_extractor)

# %%
temp_df=smartphones_copy[smartphones_copy['os']=='Other']

# %%
temp_df

# %%
df=temp_df[temp_df['model'].str.contains('Gionee|Huawei', regex=True, case=False)]

# %%
smartphones_copy.loc[df.index,'os']=' harmonyos'

# %%
smartphones_copy.loc[temp_df.index,'os']='android'

# %% [markdown]
# # ADDITIONAL AMENDMENTS

# %%
smartphones_copy['fast_charging']=smartphones_copy['fast_charging'].str.strip().str.split(' ').str.get(0).str.replace('Fast','0W').fillna('-1W')

# %%
smartphones_copy['fast_charging']=smartphones_copy['fast_charging'].str.extract(r'(-?\d+)').astype(int)

# %%
smartphones_copy['battery_capacity']=smartphones_copy['battery_capacity'].str.extract(r'(\d+)').fillna(0).astype(float)

# %%
smartphones_copy['battery_capacity'].value_counts()

# %%
smartphones_copy['RAM_capacity']=smartphones_copy['RAM_capacity'].str.extract(r'(\d+)').astype(float)

# %%
smartphones_copy['ROM_capacity']=smartphones_copy['ROM_capacity'].str.extract(r'(\d+)').astype(float)

# %%
smartphones_copy.head(2)

# %%
smartphones_copy.shape

# %%
smartphones_copy['refresh_rate']=smartphones_copy['refresh_rate'].str.extract(r'(\d+)').astype(int)

# %%
smartphones_copy.info()

# %%
smartphones_copy['price']=smartphones_copy['price'].astype(int)

# %%
smartphones_copy.info()

# %%
smartphones_copy.rename(columns={
    'index': 'index',
    'brand_name': 'brand_name',
    'model': 'model',
    'price': 'price (inr)',
    'rating': 'rating',
    'sim': 'sim',
    'has_5g': 'has_5g',
    'has_NFC': 'has_nfc',
    'has_IR_Blaster': 'has_ir_blaster',
    'processor': 'processor',
    'processor_name': 'processor_name',
    'processor_Brand': 'processor_brand',
    'num_cores': 'num_cores',
    'Speed': 'speed (ghz)',
    'ram': 'ram',
    'RAM_capacity': 'ram_capacity (gb)',
    'ROM_capacity': 'rom_capacity (gb)',
    'battery': 'battery',
    'battery_capacity': 'battery_capacity (mah)',
    'fast_charging': 'fast_charging (w)',
    'display': 'display',
    'screensize': 'screen_size (inches)',
    'resolution': 'resolution (pixels)',
    'refresh_rate': 'refresh_rate (hz)',
    'camera': 'camera',
    'num_of_rear_cameras': 'num_of_rear_cameras',
    'num_of_front_cameras': 'num_of_front_cameras',
    'rear_camera': 'rear_camera (mp)',
    'front_camera': 'front_camera (mp)',
    'card': 'card',
    'os': 'os',
    'extended_memory': 'extended_memory'
}, inplace=True)

# %%
smartphones_copy.head(2)

# %%
smartphones_copy['screen_size (inches)']=smartphones_copy['screen_size (inches)'].str.extract(r'(\d+\.\d+)').astype(float)

# %%
smartphones_copy['resolution (pixels)']=smartphones_copy['resolution (pixels)'].str.strip().str.split('px').str.get(0)

# %%
smartphones_copy.info()

# %%
smartphones_copy['num_of_rear_cameras']=smartphones_copy['num_of_rear_cameras'].astype(int)

# %%
smartphones_copy['num_of_front_cameras']=smartphones_copy['num_of_front_cameras'].str.replace('Missing','0').astype(int)

# %%
smartphones_copy['rear_camera (mp)']=smartphones_copy['rear_camera (mp)'].astype(float)

# %%
smartphones_copy['front_camera (mp)']=smartphones_copy['front_camera (mp)'].astype(float)

# %% [markdown]
# #Missing Values

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.boxenplot(x=smartphones_copy['rating'])

# %%
sns.boxplot(x=smartphones_copy['fast_charging (w)'])

# %%
plt.hist(smartphones_copy['battery_capacity (mah)'])

# %%
bat=smartphones_copy[smartphones_copy['battery_capacity (mah)']==0]

# %%
bat

# %%
x=smartphones_copy[(smartphones_copy['brand_name'].str.contains('apple')) & (smartphones_copy['battery_capacity (mah)'] > 0)]['battery_capacity (mah)']

# %%
smartphones_copy[smartphones_copy['brand_name'].str.contains('apple')]['battery_capacity (mah)'].describe()

# %%
x.mean()

# %%
median_battery = x.median()

# %%
median_battery

# %%
smartphones_copy.loc[bat.index,'battery_capacity (mah)']=median_battery

# %%
smartphones_copy['battery_capacity (mah)'].value_counts()

# %%
smartphones_copy.info()

# %%
smartphones_copy[smartphones_copy['screen_size (inches)'].isnull()]

# %%
x=smartphones_copy[~smartphones_copy['screen_size (inches)'].isnull()]

# %%
x['screen_size (inches)'].mean()

# %%
median_screen_size=x['screen_size (inches)'].median()

# %%
smartphones_copy['screen_size (inches)'].fillna(median_screen_size,inplace=True)

# %% [markdown]
# # downloading Excel File

# %%
smartphones_copy.to_excel('smartphone_cleaned_new.xlsx',index=False)
from google.colab import files
files.download('smartphone_cleaned_new.xlsx')

# %%
smartphones_copy['rating'].fillna(smartphones_copy['rating'].mean(), inplace=True)

# %%
smartphones_copy['rating'].isnull().sum()

# %%
smartphones_copy.head(1)

# %%
smartphones_copy.drop(columns=['index','sim','processor','ram','battery','display','camera','card'],inplace=True)

# %%
smartphones_copy.info()

# %%
smartphones_copy.to_csv('smartphone_cleaned_data.csv',index=False)
from google.colab import files
files.download('smartphone_cleaned_data.csv')
