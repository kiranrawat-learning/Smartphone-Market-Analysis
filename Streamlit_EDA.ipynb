# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
smartphones=pd.read_csv('/content/drive/MyDrive/dataset/smartphones (3).csv')

# %%
smartphones['brand_name'].unique().tolist()
# Out:
# ['oneplus',
#  'samsung',
#  'motorola',
#  'realme',
#  'apple',
#  'xiaomi',
#  'nothing',
#  'oppo',
#  'vivo',
#  'poco',
#  'iqoo',
#  'jio',
#  'gionee',
#  'tecno',
#  'tesla',
#  'google',
#  'infinix',
#  'cola',
#  'letv',
#  'ikall',
#  'leeco',
#  'duoqin',
#  'nokia',
#  'lava',
#  'honor',
#  'nubia',
#  'redmi',
#  'asus',
#  'itel',
#  'royole',
#  'sony',
#  'oukitel',
#  'vertu',
#  'blu',
#  'lyf',
#  'huawei',
#  'zte',
#  'lenovo',
#  'lg',
#  'micromax',
#  'leitz',
#  'cat',
#  'doogee',
#  'tcl',
#  'sharp',
#  'blackview']

# %% [markdown]
# # smartphones.groupby('brand_name')['model'].apply(list).get(selected_brand,[])

# %%
smartphones.groupby('brand_name')['model'].apply(list).get("apple",[])
# Out:
# ['Apple iPhone 14',
#  'Apple iPhone 13',
#  'Apple iPhone 14 Pro Max',
#  'Apple iPhone 11',
#  'Apple iPhone 14 Plus',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 14 Pro',
#  'Apple iPhone 12',
#  'Apple iPhone 11 (128GB)',
#  'Apple iPhone 12 Mini',
#  'Apple iPhone 15 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 9',
#  'Apple iPhone 14 Pro Max (256GB)',
#  'Apple iPhone 14 (256GB)',
#  'Apple iPhone XR2',
#  'Apple iPhone 13 Mini',
#  'Apple iPhone 14 Mini',
#  'Apple iPhone 14 Pro Max (1TB)',
#  'Apple iPhone 12 (128GB)',
#  'Apple iPhone 14 Plus (256GB)',
#  'Apple iPhone 13 (256GB)',
#  'Apple iPhone 12 Mini (128GB)',
#  'Apple iPhone 15 Ultra',
#  'Apple iPhone 14 Pro (256GB)',
#  'Apple iPhone SE 3 2022',
#  'Apple iPhone 15 Pro',
#  'Apple iPhone 13 Pro (256GB)',
#  'Apple iPhone 11 Pro Max',
#  'Apple iPhone 7s',
#  'Apple iPhone 12 Pro (512GB)',
#  'Apple iPhone 14 (512GB)',
#  'Apple iPhone SE 2020',
#  'Apple iPhone 13 Pro Max (256GB)',
#  'Apple iPhone 15',
# ...

# %%
smartphones.head(1)
# Out:
#   brand_name          model  price (inr)  rating  has_5g  has_nfc  \
# 0    oneplus  OnePlus 11 5G        54999    89.0    True     True
#
#    has_ir_blaster     processor_name processor_brand  num_cores  ...  \
# 0           False  Snapdragon 8 Gen2      snapdragon  Octa Core  ...
#
#    resolution (pixels)  refresh_rate (hz)  num_of_rear_cameras  \
# 0         1440 x 3216                 120                    3
#
#    num_of_front_cameras  rear_camera (mp)  front_camera (mp) total_pixel  \
# 0                     1              50.0               16.0     4631040
#
#         os  extended_memory  budget_categorisation
# 0  android                0                Premium
#
# [1 rows x 26 columns]

# %%
smartphones.groupby('budget_categorisation')['price (inr)'].mean()
# Out:
# budget_categorisation
# Budget              14843.089256
# Flagship           133197.409091
# Mid-Range           35099.672897
# Premium             70203.716814
# ultra Luxurious    396247.250000
# Name: price (inr), dtype: float64

# %%
smartphones.groupby('budget_categorisation')['price (inr)'].describe()
# Out:
#                        count           mean            std       min  \
# budget_categorisation
# Budget                 605.0   14843.089256    5327.483167    3499.0
# Flagship                44.0  133197.409091   24675.585109  101999.0
# Mid-Range              214.0   35099.672897    7052.576557   25289.0
# Premium                113.0   70203.716814   13772.842811   50990.0
# ultra Luxurious          4.0  396247.250000  207101.172997  214990.0
#
#                              25%       50%       75%       max
# budget_categorisation
# Budget                  10799.00   14799.0   18990.0   25000.0
# Flagship               113242.25  129900.0  148400.0  199990.0
# Mid-Range               28999.00   32999.0   39999.0   49999.0
# Premium                 58990.00   69990.0   79999.0   99999.0
# ultra Luxurious        233746.75  359999.5  522500.0  650000.0

# %%
avg_price = smartphones.groupby('brand_name')['rating'].mean().sort_values(ascending=False)
avg_price
# Out:
# brand_name
# leitz        89.000000
# lenovo       88.000000
# sharp        88.000000
# royole       87.000000
# doogee       86.000000
# asus         85.751178
# zte          85.500000
# nothing      85.200000
# blu          85.000000
# nubia        84.333333
# lg           84.086083
# tesla        83.000000
# iqoo         82.218750
# oneplus      81.857928
# sony         80.724055
# motorola     79.962173
# huawei       79.455703
# oukitel      79.333333
# xiaomi       78.741226
# oppo         78.699426
# poco         78.689226
# samsung      78.667666
# duoqin       78.258248
# cat          78.258248
# honor        78.193577
# google       77.465464
# redmi        77.333333
# vivo         77.305169
# apple        76.859054
# realme       76.539085
# itel         76.532423
# infinix      76.353733
# nokia        75.982673
# lava         75.314562
# jio          74.693686
# gionee       74.505499
# cola         74.000000
# tecno        73.955045
# letv         72.172165
# ...

# %%
sns.barplot(x=avg_price.index, y=avg_price.values, palette="Blues_r")
# Out:
# <ipython-input-10-8844ccd03e7c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price.index, y=avg_price.values, palette="Blues_r")
# <Axes: xlabel='brand_name'>

# %%
brand_data=smartphones[smartphones['brand_name'] == "apple"]
brand_data
# Out:
#     brand_name                            model  price (inr)     rating  \
# 6        apple                  Apple iPhone 14        65999  81.000000
# 15       apple                  Apple iPhone 13        62999  79.000000
# 27       apple          Apple iPhone 14 Pro Max       129990  76.000000
# 33       apple                  Apple iPhone 11        38999  73.000000
# 56       apple             Apple iPhone 14 Plus        74999  82.000000
# 76       apple              Apple iPhone 13 Pro       119900  83.000000
# 100      apple              Apple iPhone 14 Pro       119990  75.000000
# 111      apple                  Apple iPhone 12        51999  74.000000
# 136      apple          Apple iPhone 11 (128GB)        46999  75.000000
# 149      apple             Apple iPhone 12 Mini        40999  74.000000
# 152      apple          Apple iPhone 15 Pro Max       142990  79.000000
# 161      apple          Apple iPhone 13 Pro Max       129900  84.000000
# ...

# %%
brand_data['budget_categorisation'].value_counts()
# Out:
# budget_categorisation
# Flagship     20
# Premium      18
# Mid-Range     8
# Name: count, dtype: int64

# %%
brand_data[brand_data['budget_categorisation']=='Flagship']
# Out:
#     brand_name                            model  price (inr)  rating  has_5g  \
# 27       apple          Apple iPhone 14 Pro Max       129990    76.0    True
# 76       apple              Apple iPhone 13 Pro       119900    83.0    True
# 100      apple              Apple iPhone 14 Pro       119990    75.0    True
# 152      apple          Apple iPhone 15 Pro Max       142990    79.0    True
# 161      apple          Apple iPhone 13 Pro Max       129900    84.0    True
# 209      apple  Apple iPhone 14 Pro Max (256GB)       139990    77.0    True
# 288      apple    Apple iPhone 14 Pro Max (1TB)       182999    78.0    True
# 398      apple            Apple iPhone 15 Ultra       149900    79.0    True
# 416      apple      Apple iPhone 14 Pro (256GB)       129990    76.0    True
# 444      apple              Apple iPhone 15 Pro       130990    75.0    True
# 521      apple      Apple iPhone 13 Pro (256GB)       129900    83.0    True
# ...

# %%
brand_data['price (inr)'].mean()
# Out:
# np.float64(95966.52173913043)

# %%
brand_data['has_5g'].value_counts().plot(kind='pie', autopct="%0.1f%%",
                                                  textprops={'fontsize': 12, 'fontweight': 'bold'})
# Out:
# <Axes: ylabel='count'>

# %%
brand_data['has_ir_blaster'].value_counts().plot(kind='pie', autopct="%0.1f%%",
                                                  textprops={'fontsize': 12, 'fontweight': 'bold'})
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(12, 6))

sns.barplot(data=brand_data, x='processor_brand', y='price (inr)',palette='viridis')
plt.xticks(rotation=45)
plt.title("Processor Brand vs Price", fontsize=14, fontweight='bold')
plt.ylabel("Price (INR)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1,1), title="Brand", fontsize=10)
# Out:
# <ipython-input-15-fdbfe056aa88>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=brand_data, x='processor_brand', y='price (inr)',palette='viridis')
# <ipython-input-15-fdbfe056aa88>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1,1), title="Brand", fontsize=10)

# %%
pd.set_option('display.max_columns', None)

# %%
brand_data.head(1)
# Out:
#   brand_name            model  price (inr)  rating  has_5g  has_nfc  \
# 6      apple  Apple iPhone 14        65999    81.0    True     True
#
#    has_ir_blaster processor_name processor_brand  num_cores  speed (ghz)  \
# 6           False     Bionic A15    apple bionic  Hexa Core         3.22
#
#    ram_capacity (gb)  rom_capacity (gb)  battery_capacity (mah)  \
# 6                6.0              128.0                  3279.0
#
#    fast_charging (w)  screen_size (inches) resolution (pixels)  \
# 6                  0                   6.1        1170 x 2532
#
#    refresh_rate (hz)  num_of_rear_cameras  num_of_front_cameras  \
# 6                 60                    2                     1
#
#    rear_camera (mp)  front_camera (mp)  total_pixel   os extended_memory  \
# 6              12.0               12.0      2962440  ios               0
#
#   budget_categorisation
# 6               Premium

# %%
plt.figure(figsize=(12, 12))

sns.barplot(data=brand_data, x='ram_capacity (gb)', y=brand_data['model'],palette='viridis')
plt.xticks(rotation=45)
plt.title("Processor Brand vs Price", fontsize=14, fontweight='bold')
plt.ylabel("Price (INR)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(bbox_to_anchor=(1,1), title="Brand", fontsize=10)
# Out:
# <ipython-input-21-552beaf9df74>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=brand_data, x='ram_capacity (gb)', y=brand_data['model'],palette='viridis')
# <ipython-input-21-552beaf9df74>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1,1), title="Brand", fontsize=10)

# %%
brand_data.shape
# Out:
# (46, 26)

# %%
    ram_count = brand_data['ram_capacity (gb)'].value_counts().reset_index()
    ram_count.columns = ['RAM Capacity (GB)', 'Number of Models']
    ram_count
# Out:
#    RAM Capacity (GB)  Number of Models
# 0                6.0                23
# 1                4.0                14
# 2                8.0                 4
# 3                3.0                 3
# 4               64.0                 2

# %%
processor_count = brand_data['processor_brand'].value_counts().reset_index()
processor_count.columns = ['Processor Brand', 'Number of Models']
processor_count
# Out:
#   Processor Brand  Number of Models
# 0    apple bionic                45
# 1           apple                 1

# %%
phone_dta=brand_data[brand_data['model'] == "Apple iPhone 15 Plus"]
phone_dta=np.transpose(phone_dta)
pd.DataFrame(phone_dta)
# Out:
#                                          892
# brand_name                             apple
# model                   Apple iPhone 15 Plus
# price (inr)                            84990
# rating                                  75.0
# has_5g                                  True
# has_nfc                                 True
# has_ir_blaster                         False
# processor_name                    Bionic A16
# processor_brand                 apple bionic
# num_cores                          Hexa Core
# speed (ghz)                              NaN
# ram_capacity (gb)                        8.0
# rom_capacity (gb)                      128.0
# battery_capacity (mah)                4532.0
# fast_charging (w)                          0
# screen_size (inches)                    6.71
# resolution (pixels)             1284 x 2778
# refresh_rate (hz)                        120
# num_of_rear_cameras                        2
# num_of_front_cameras                       1
# ...

# %%
  front_camera = brand_data['front_camera (mp)'].value_counts().reset_index()
  front_camera.columns = ['Camera (MP)', 'Number of Models']
  front_camera['Type'] = 'Front Camera'

  rear_camera = brand_data['rear_camera (mp)'].value_counts().reset_index()
  rear_camera.columns = ['Camera (MP)', 'Number of Models']
  rear_camera['Type'] = 'Rear Camera'

# %%
camera_data = pd.concat([front_camera, rear_camera])
camera_data
# Out:
#    Camera (MP)  Number of Models          Type
# 0         12.0                39  Front Camera
# 1          7.0                 5  Front Camera
# 2         13.0                 1  Front Camera
# 3         10.0                 1  Front Camera
# 0         12.0                34   Rear Camera
# 1         48.0                 8   Rear Camera
# 2         50.0                 3   Rear Camera
# 3         13.0                 1   Rear Camera

# %%
sns.barplot(data=camera_data, x='Camera (MP)', y='Number of Models', hue='Type',palette={"Front Camera": "red", "Rear Camera": "blue"})
# Out:
# <Axes: xlabel='Camera (MP)', ylabel='Number of Models'>

# %%
  ram_count = brand_data['ram_capacity (gb)'].value_counts().reset_index()
  ram_count.columns = ['Storage (GB)', 'Number of Models']
  ram_count['type']='RAM Capacity (GB)'

  rom_count = brand_data['rom_capacity (gb)'].value_counts().reset_index()
  rom_count.columns = ['Storage (GB)', 'Number of Models']
  rom_count['type']='Internal Storage'
  storage=pd.concat([ram_count,rom_count])
  storage
# Out:
#    Storage (GB)  Number of Models               type
# 0           6.0                23  RAM Capacity (GB)
# 1           4.0                14  RAM Capacity (GB)
# 2           8.0                 4  RAM Capacity (GB)
# 3           3.0                 3  RAM Capacity (GB)
# 4          64.0                 2  RAM Capacity (GB)
# 0         128.0                16   Internal Storage
# 1         256.0                11   Internal Storage
# 2          64.0                 7   Internal Storage
# 3         512.0                 5   Internal Storage
# 4           1.0                 4   Internal Storage
# 5          32.0                 1   Internal Storage

# %%
sns.barplot(data=storage, x='Storage (GB)', y='Number of Models', hue='type',
                palette={"RAM Capacity (GB)": "red", "Internal Storage": "blue"})
# Out:
# <Axes: xlabel='Storage (GB)', ylabel='Number of Models'>
